# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.shape
# Out:
# (301, 9)

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#Checking all unique values from categorical data

print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
#check missing or null values

df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df["Current Year"] = 2024

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Current Year
# 0      Dealer       Manual      0          2024
# 1      Dealer       Manual      0          2024
# 2      Dealer       Manual      0          2024
# 3      Dealer       Manual      0          2024
# 4      Dealer       Manual      0          2024

# %%
df.drop(['Car_Name'],axis =1,inplace = True)

# %%
df['Car Year'] = df['Current Year']- df['Year']

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  Car Year
# 0       Manual      0          2024        10
# 1       Manual      0          2024        11
# 2       Manual      0          2024         7
# 3       Manual      0          2024        13
# 4       Manual      0          2024        10

# %%
df.drop(['Year','Current Year'],axis =1,inplace = True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car Year
# 0       Manual      0        10
# 1       Manual      0        11
# 2       Manual      0         7
# 3       Manual      0        13
# 4       Manual      0        10

# %%
df1 = pd.get_dummies(data=df, columns=['Fuel_Type','Seller_Type','Transmission'], dtype='int')

# %%
df1.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Car Year  Fuel_Type_CNG  \
# 0           3.35           5.59       27000      0        10              0
# 1           4.75           9.54       43000      0        11              0
# 2           7.25           9.85        6900      0         7              0
# 3           2.85           4.15        5200      0        13              0
# 4           4.60           6.87       42450      0        10              0
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                 0                 1                   1
# 1                 1                 0                   1
# 2                 0                 1                   1
# 3                 0                 1                   1
# 4                 1                 0                   1
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# 0                       0                       0                    1
# 1                       0                       0                    1
# 2                       0                       0                    1
# 3                       0                       0                    1
# 4                       0                       0                    1

# %%
df1.shape
# Out:
# (301, 12)

# %%
df1.drop(['Transmission_Automatic','Seller_Type_Individual','Fuel_Type_Petrol'],axis = 1,inplace = True)

# %%
df1.shape
# Out:
# (301, 9)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df1.drop(['Selling_Price'],axis = 1)
y = df1.Selling_Price

# %%
X.sample(4)
# Out:
#      Present_Price  Kms_Driven  Owner  Car Year  Fuel_Type_CNG  \
# 297          5.900       60000      0         9              0
# 88           6.050       47000      0        11              0
# 182          0.580       30000      0        11              0
# 146          0.787       15000      0        10              0
#
#      Fuel_Type_Diesel  Seller_Type_Dealer  Transmission_Manual
# 297                 0                   1                    1
# 88                  0                   1                    1
# 182                 0                   0                    1
# 146                 0                   0                    1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9073724202200758

# %%
model.predict([[18.61,11000,0,14,0,0,0,1]])
# Out:
# array([6.59480601])

# %%
import pickle
with open('carprice.pickle','wb') as f:
    pickle.dump(model,f)

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([ 4.37245806e+00,  2.65718720e+00, -9.78137440e-01,  5.26291004e+00,
#         8.52964659e-01,  1.61932270e+01,  5.19795729e+00,  3.83800348e+00,
#         9.61397837e-01,  1.29354959e+00, -1.51831439e-01,  7.78810398e+00,
#         5.72793351e+00,  1.79500617e+01,  1.02264120e+01,  6.10573559e+00,
#         6.02364655e-01,  4.51364921e+00, -3.43697432e+00,  2.84890611e+00,
#        -3.94099455e+00,  4.33506368e+00,  1.81755413e-01,  8.20860878e+00,
#         6.27027656e+00,  2.69203492e-01,  7.02329296e-01, -2.14858372e+00,
#         7.95702597e+00,  9.42259450e+00,  3.01074242e+00,  2.36119666e+00,
#         6.09547159e+00,  3.76770155e+00,  8.01439054e+00,  3.93651612e+00,
#         9.71194867e+00,  2.07576662e-01,  3.22363378e+00, -5.98166697e-01,
#         4.55541613e+00,  4.41001363e+00,  5.73628112e+00,  2.63673917e+00,
#         5.92819075e+00,  5.14082326e+00, -5.69647319e-01,  1.52360035e+01,
#         1.40606445e+00,  4.27448752e+00,  1.32893443e+00,  1.42823500e+01,
#         6.13413400e+00,  1.53899848e-02,  4.46639621e+00,  7.11242651e+00,
#         1.63428313e+01,  1.98967066e+00,  9.01197382e+00,  2.01984761e+01,
#         7.94126859e-01])

# %%
import seaborn as sns
sns.distplot(y_test-predictions)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,predictions)
plt.show()
